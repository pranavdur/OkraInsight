# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# note use of % instead of !
# %cd drive/MyDrive/Colab\ Notebooks
# Out:
# /content
# /content/drive/MyDrive/Colab Notebooks

# %%
# !ssh-keygen -t ed25519 -C "pranavdur@github.com"
# !ssh-keyscan -t ed25519 github.com >> ~/.ssh/known_hosts
# !cat /root/.ssh/id_ed25519.pub

# goto github settings, add new ssh key using the above .pub contents
# Out:
# Generating public/private ed25519 key pair.
# Enter file in which to save the key (/root/.ssh/id_ed25519):
# /root/.ssh/id_ed25519 already exists.
# Overwrite (y/n)? y
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /root/.ssh/id_ed25519
# Your public key has been saved in /root/.ssh/id_ed25519.pub
# The key fingerprint is:
# SHA256:pbOlBpJSMcO2Iku5zMLXSWqV8EtJCpXhjaj7s1I4MFw pranavdur@github.com
# The key's randomart image is:
# +--[ED25519 256]--+
# |  .+*            |
# | .oE==           |
# |..++*oo   .      |
# |=+.o.O   o       |
# |B=o.O + S .      |
# |=*.= = . =       |
# |ooo     +        |
# |...    .         |
# | .oo             |
# +----[SHA256]-----+
# # github.com:22 SSH-2.0-babeld-0ae455d31
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIJPQDHpHwFRj/T2eGh9lPKUvLUAzQ2AynTZslQasiFY+ pranavdur@github.com

# %%
# !git clone git@github.com:pranavdur/OkraInsight.git
# Out:
# Cloning into 'OkraInsight'...
# remote: Enumerating objects: 1046, done.
# remote: Counting objects: 100% (351/351), done.
# remote: Compressing objects: 100% (225/225), done.
# remote: Total 1046 (delta 108), reused 326 (delta 87), pack-reused 695 (from 1)
# Receiving objects: 100% (1046/1046), 585.03 MiB | 14.70 MiB/s, done.
# Resolving deltas: 100% (226/226), done.
# Updating files: 100% (289/289), done.
# Filtering content: 100% (23/23), 202.89 MiB | 24.95 MiB/s, done.
# fatal: cannot exec '/content/drive/MyDrive/Colab Notebooks/OkraInsight/.git/hooks/post-checkout': Permission denied
# Encountered 66 file(s) that should have been pointers, but weren't:
# 	.ipynb_checkpoints/deeplabv3_scripted.pt
# 	__artifacts/colab_training_pipeline.png
# 	__artifacts/gpu_usage.png
# 	__artifacts/ground_truth.png
# 	__artifacts/input_image.png
# 	__artifacts/ios_inference_pipeline.png
# 	__artifacts/ios_sim-deeplabv3-segment.png
# 	__artifacts/ios_sim-input.png
# ...
